# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv('surat_uncleaned.csv')

# %%
df.head(10)
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_name   4525 non-null   object
#  1   areaWithType    4525 non-null   object
#  2   square_feet     4525 non-null   object
#  3   transaction     4421 non-null   object
#  4   status          4524 non-null   object
#  5   floor           4480 non-null   object
#  6   furnishing      4185 non-null   object
#  7   facing          3936 non-null   object
#  8   description     3154 non-null   object
#  9   price_per_sqft  4157 non-null   object
#  10  price           4525 non-null   object
# dtypes: object(11)
# memory usage: 389.0+ KB

# %%
df.dtypes
# Out:
# property_name     object
# areaWithType      object
# square_feet       object
# transaction       object
# status            object
# floor             object
# furnishing        object
# facing            object
# description       object
# price_per_sqft    object
# price             object
# dtype: object

# %%
df.describe().T
# Out:
#                count unique  \
# property_name   4525   1992
# areaWithType    4525      6
# square_feet     4525   1399
# transaction     4421     38
# status          4524    138
# floor           4480    222
# furnishing      4185     78
# facing          3936    176
# description     3154   2588
# price_per_sqft  4157   2134
# price           4525    841
#
#                                                               top  freq
# property_name              3 BHK Apartment for Sale in Vesu Surat    93
# areaWithType                                           Super Area  2599
# square_feet                                             1000 sqft    77
# transaction                                                Resale  2197
# status                                              Ready to Move  3078
# floor                                                      Resale   431
# furnishing                                            Unfurnished  2322
# ...

# %%
df.describe(include='all').T
# Out:
#                count unique  \
# property_name   4525   1992
# areaWithType    4525      6
# square_feet     4525   1399
# transaction     4421     38
# status          4524    138
# floor           4480    222
# furnishing      4185     78
# facing          3936    176
# description     3154   2588
# price_per_sqft  4157   2134
# price           4525    841
#
#                                                               top  freq
# property_name              3 BHK Apartment for Sale in Vesu Surat    93
# areaWithType                                           Super Area  2599
# square_feet                                             1000 sqft    77
# transaction                                                Resale  2197
# status                                              Ready to Move  3078
# floor                                                      Resale   431
# furnishing                                            Unfurnished  2322
# ...

# %%
df.columns.to_list()
# Out:
# ['property_name',
#  'areaWithType',
#  'square_feet',
#  'transaction',
#  'status',
#  'floor',
#  'furnishing',
#  'facing',
#  'description',
#  'price_per_sqft',
#  'price']

# %%
df.describe().T.plot(kind='bar')
# Out:
# <Axes: >

# %%
from plotly import express

for column in ['property_name',
 'areaWithType',
 'square_feet',
 'transaction',
 'status',
 'floor',
 'furnishing',
 'facing',
 'description',
 'price_per_sqft',
 'price']:
    express.histogram(data_frame=df, x=column).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby('areaWithType')['price'].sum()
# Out:
# areaWithType
# Built Area     ₹22 Lac ₹32 Lac ₹40 Lac ₹1 Lac ₹3.5 Lac ₹13 La...
# Carpet Area    ₹33.8 Lac ₹47 Lac ₹42.1 Lac ₹44.1 Lac ₹40 Lac ...
# Plot Area      ₹42 Lac ₹24 Lac ₹49 Lac ₹40 Lac ₹33 Lac ₹12 La...
# Status                          ₹30 Lac ₹15 Lac ₹22 Lac ₹30 Lac
# Super Area     ₹45.4 Lac ₹44.6 Lac ₹45 Lac ₹43.2 Lac ₹44.3 La...
# Transaction                                     ₹12 Lac ₹24 Lac
# Name: price, dtype: object

# %%
df.groupby('areaWithType')['price'].size()
# Out:
# areaWithType
# Built Area       35
# Carpet Area    1671
# Plot Area       214
# Status            4
# Super Area     2599
# Transaction       2
# Name: price, dtype: int64

# %%
df.groupby('areaWithType')['price'].size().plot()
# Out:
# <Axes: xlabel='areaWithType'>

# %%
from wordcloud import WordCloud

reviews_text = ' '.join(df['facing'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(reviews_text)
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Reviews')
plt.axis('off')
plt.show()
